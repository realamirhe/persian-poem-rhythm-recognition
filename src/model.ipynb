# %% [markdown]
# # Pre setup
# - remove extra sample data directory

# %%
# !rm -rf sample_data

# %% [markdown]
# # Data
# - uploading data
# - add dataloader generator

# %%
# !unzip data.zip
# !rm data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#   inflating: data/DSATrn-v2.00.txt
#   inflating: data/DSATst-v2.00.txt
#   inflating: data/DSUSTrn-v2.00.txt
#   inflating: data/DSUSTst-v2.00.txt
#   inflating: data/DSVNTrn-v2.00.txt
#   inflating: data/DSVNTst-v2.00.txt

# %%
def read_lines(path):
  with open(path) as file:
    return file.readlines()

def make_data_loader(develeopment):
  postfix = 'Trn' if develeopment else 'Tst'
  postfix += '-v2.00.txt'

  udashs = read_lines(f"./data/DSUS{postfix}")
  answer = read_lines(f"./data/DSA{postfix}")
  tokens = read_lines(f"./data/DSVN{postfix}")

  tokens = tokens[: len(answer)]

  for t, u, a in zip(tokens, udashs, answer):
    yield t.strip(), u.strip(), a.strip()

# %%
for pack in make_data_loader(True):
  print(pack)
  break
# Out:
# ('امروز قدر پند عزیزان شناختم*یا رب روان ناصح ما از تو شاد باد', '--UU--UU--UU--*--U-U----U-U--', '1003')

# %% [markdown]
# # Phoneme

# %%
# !pip install --upgrade https://github.com/PasaOpasen/PersianG2p/tarball/master
# Out:
# Collecting https://github.com/PasaOpasen/PersianG2p/tarball/master
#   Downloading https://github.com/PasaOpasen/PersianG2p/tarball/master
#      | 36.9 MB 2.0 MB/s
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 5.3 MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from PersianG2p==0.3.1) (2.1.0)
# Collecting num2fawords
#   Downloading num2fawords-1.1-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from PersianG2p==0.3.1) (1.19.5)
# Collecting libwapiti>=0.2.1
#   Downloading libwapiti-0.2.1.tar.gz (233 kB)
#      |████████████████████████████████| 233 kB 46.7 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 37.4 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm->PersianG2p==0.3.1) (1.15.0)
# Building wheels for collected packages: PersianG2p, nltk, libwapiti
#   Building wheel for PersianG2p (setup.py) ... done
#   Created wheel for PersianG2p: filename=PersianG2p-0.3.1-py3-none-any.whl size=924737 sha256=c590738a30246b24bb3506f9714f04594d593e6ee013f2a87735efbfaa445cbe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kdlh1t6l/wheels/89/e2/83/42f24906d93a4bb43f2e4879bde3269fa17bacf999875ed045
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394487 sha256=dcbc2cc274b32d5f81e9eba15c1db38dd94e6e98612c65624900680b4e83a6c4
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/0c/d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp37-cp37m-linux_x86_64.whl size=154606 sha256=53d20fbaf08cf39aa90e961a0744c44dac34e08d5ca5c355ac6a6807c5f9ffdb
#   Stored in directory: /root/.cache/pip/wheels/ab/b2/5b/0fe4b8f5c0e65341e8ea7bb3f4a6ebabfe8b1ac31322392dbf
# Successfully built PersianG2p nltk libwapiti
# Installing collected packages: nltk, libwapiti, num2fawords, hazm, PersianG2p
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed PersianG2p-0.3.1 hazm-0.7.0 libwapiti-0.2.1 nltk-3.3 num2fawords-1.1

# %%
from PersianG2p import Persian_g2p_converter
PersianG2PConvertor = Persian_g2p_converter(use_large=True)
g2p = PersianG2PConvertor.transliterate

print(pack[0])
g2p(pack[0].replace("*", " "), tidy=False)
# Out:
# امروز قدر پند عزیزان شناختم*یا رب روان ناصح ما از تو شاد باد
# ' e m r u z   q a d r  pand azizAn  S e n A x t a m   y A  rab  r a v A n  nAseh  m A   a z   t o  SAd bAd'

# %%
g2p('فعلاتن مفاعلن فعلن', tidy=False)
# Out:
مفتعلن فاعلن مفتعلن فاعلن
منسرح مثمن مطوي مکشوف
1020
- U - U - - - - U - U - - -
fA?elAto maf?ulon fA?elAto maf?ulon
فاعلات مفعولن فاعلات مفعولن
مقتضب مثمن مطوي مقطوع
1021
- U U - - U U - - U -
mofta?elon mofta?elon fA?elon
مفتعلن مفتعلن فاعلن
سريع مسدس مطوي مکشوف
1022
U - - U - - U - - U - -
fa?ulon fa?ulon fa?ulon fa?ulon
فعولن فعولن فعولن فعولن
متقارب مثمن سالم
1023
U - - U - - U - - U -
fa?ulon fa?ulon fa?ulon fa?al
فعولن فعولن فعولن فعل
متقارب مثمن محذوف
1024
- U U - - U U - - U U - - U U -
mofta?elon mofta?elon mofta?elon mofta?elon
مفتعلن مفتعلن مفتعلن مفتعلن
رجز مثمن مطوي
1025
U U - - U U - - U U - - U U - -
fa?alAton fa?alAton fa?alAton fa?alAton
فعلاتن فعلاتن فعلاتن فعلاتن
رمل مثمن مخبون
1026
U U - - U U - - U U -
fA?elAton fa?alAton fa?alon
فعلاتن فعلاتن فعلن
رمل مسدس مخبون محذوف
1027
U - - U U - - U U - - U U - -
mafA?ilo mafA?ilo mafA?ilo fa?ulon
مفاعيل مفاعيل مفاعيل فعولن
هزج مثمن مکفوف محذوف
1028
U U - - U - U - U U - - U - U -
fa?alAton mafA?elon fa?alAton mafA?elon
فعلاتن مفاعلن فعلاتن مفاعلن
خفيف مثمن مخبون
1029
- - U U - U - U - - -
maf?ulo mafA?elon mafA?ilon
مفعول مفاعلن مفاعيلن
هزج مسدس اخرب مقبوض سالم
1030
- U - - - U - - - U - - - U - -
fA?elAton fA?elAton fA?elAton fA?elAton
فاعلاتن فاعلاتن فاعلاتن فاعلاتن
رمل مثمن سالم
1031
- - U - U U - - - U - U U -
mostaf?elon fa?alon mostaf?elon fa?alon
مستفعلن فعلن مستفعلن فعلن
بسيط مثمن مخبون"""

# %% [markdown]
# ## Prostody Helpers

# %%
ans2ud = {}
ud2phoneme = {}
categories = []
informative_prostody = {}
prostody_categories = prostody_categories.splitlines()

for i in range(0, len(prostody_categories), 5):
  _ans = prostody_categories[i]
  _ud = prostody_categories[i + 1].replace(" ", "",  -1)
  _phoneme = prostody_categories[i + 2]
  _arabic = prostody_categories[i + 3]
  _persian = prostody_categories[i + 4]
  ans2ud[_ans] = _ud
  ud2phoneme[_ud] = _phoneme
  categories.append(_ans)
  informative_prostody[_ud] = {
    "ans": _ans,
    "phoneme": _phoneme,
    "arabic": _arabic,
    "persian": _persian,
  }

# %%
from sklearn import preprocessing

categoryEncoder = preprocessing.LabelEncoder()
categories = categoryEncoder.fit_transform(categories)

# %%
categories[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# # Modeling

# %%
# !pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.61.13-py3-none-any.whl (221 kB)
#      |████████████████████████████████| 221 kB 5.2 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2.23.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.8 MB/s
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (4.62.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 45.9 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (2019.12.20)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from simpletransformers) (1.19.5)
# Collecting streamlit
#   Downloading streamlit-0.87.0-py2.py3-none-any.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 40.0 MB/s
# Collecting datasets
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 52.1 MB/s
# Collecting tensorboardx
#   Downloading tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 49.6 MB/s
# Collecting tokenizers
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 14.2 MB/s
# Collecting wandb>=0.10.32
#   Downloading wandb-0.12.1-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 38.7 MB/s
# Collecting transformers>=4.2.0
#   Downloading transformers-4.10.0-py3-none-any.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 34.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.2.0->simpletransformers) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=4.2.0->simpletransformers) (21.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 24.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=4.2.0->simpletransformers) (4.6.4)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.16-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.6 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 39.6 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers>=4.2.0->simpletransformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=4.2.0->simpletransformers) (2.4.7)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 47.0 MB/s
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.3.1-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 47.1 MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (3.17.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.8.2)
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 6.0 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.10.32->simpletransformers) (2.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->simpletransformers) (1.24.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.3.4)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.8.1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 48.7 MB/s
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 43.6 MB/s
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (0.70.12.2)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->simpletransformers) (3.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=4.2.0->simpletransformers) (3.5.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->simpletransformers) (2018.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.2.0->simpletransformers) (1.0.1)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.1.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (21.2.0)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 48.9 MB/s
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.0-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 17.8 MB/s
# Collecting base58
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (5.1.1)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Collecting watchdog
#   Downloading watchdog-2.1.5-py3-none-manylinux2014_x86_64.whl (75 kB)
#      |████████████████████████████████| 75 kB 3.8 MB/s
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: astor in /usr/local/lib/python3.7/dist-packages (from streamlit->simpletransformers) (0.8.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.6.0)
# Collecting ipykernel>=5.1.2
#   Downloading ipykernel-6.3.1-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 43.6 MB/s
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.7/dist-packages (from pydeck>=0.1.dev5->streamlit->simpletransformers) (5.0.5)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.5)
# Collecting ipython<8.0,>=7.23.1
#   Downloading ipython-7.27.0-py3-none-any.whl (787 kB)
#      |████████████████████████████████| 787 kB 38.6 MB/s
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.12.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.18.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (2.6.1)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.20-py3-none-any.whl (370 kB)
#      |████████████████████████████████| 370 kB 48.9 MB/s
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (22.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.11.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (4.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.7.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit->simpletransformers) (0.5.1)
# Building wheels for collected packages: subprocess32, pathtools, seqeval, blinker
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=1adfd8df3d59efe89780ff7cfb46ee36445b677ae69e1c68f99cf25718709ff4
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=d859cbbf1d7888e657b125c147da85353f198aa742d47be584b2c7cb2d5f6121
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=da6a77f43acf54ef51e92bbb9c1331dfe8aac97da1e956c03a4e54fe9dc3a8bf
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=3b87bbd09f1310f7e18ae277b91610825aafb30d609efa5fd0a82f0bac5c589c
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built subprocess32 pathtools seqeval blinker
# Installing collected packages: prompt-toolkit, ipython, ipykernel, smmap, gitdb, xxhash, watchdog, validators, tokenizers, subprocess32, shortuuid, sentry-sdk, sacremoses, pyyaml, pydeck, pathtools, huggingface-hub, GitPython, fsspec, docker-pycreds, configparser, blinker, base58, wandb, transformers, tensorboardx, streamlit, seqeval, sentencepiece, datasets, simpletransformers
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Attempting uninstall: ipython
#     Found existing installation: ipython 5.5.0
#     Uninstalling ipython-5.5.0:
#       Successfully uninstalled ipython-5.5.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.20 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.3.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.27.0 which is incompatible.
# Successfully installed GitPython-3.1.18 base58-2.1.0 blinker-1.4 configparser-5.0.2 datasets-1.11.0 docker-pycreds-0.4.0 fsspec-2021.8.1 gitdb-4.0.7 huggingface-hub-0.0.16 ipykernel-6.3.1 ipython-7.27.0 pathtools-0.1.2 prompt-toolkit-3.0.20 pydeck-0.7.0 pyyaml-5.4.1 sacremoses-0.0.45 sentencepiece-0.1.96 sentry-sdk-1.3.1 seqeval-1.2.2 shortuuid-1.0.1 simpletransformers-0.61.13 smmap-4.0.0 streamlit-0.87.0 subprocess32-3.5.4 tensorboardx-2.4 tokenizers-0.10.3 transformers-4.10.0 validators-0.18.2 wandb-0.12.1 watchdog-2.1.5 xxhash-2.0.2

# %%
import torch
from simpletransformers.classification import ClassificationModel, ClassificationArgs
from sklearn.metrics import accuracy_score
import pandas as pd
import logging


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
# Preparing train data
def process_line(prop):
  t, u, a = prop
  if (a == '@#$%'):
    return None
  
  t1, t2 = t.split("*")

  token_1 = g2p(t1, tidy=False).replace("  ", "#", -1).replace(" ", "", -1).replace("#", " ", -1)
  token_2 = g2p(t2, tidy=False).replace("  ", "#", -1).replace(" ", "", -1).replace("#", " ", -1)

  u1, u2 = u.split("*")

  return [f'{t1} {u1} {t2} {u2}', categoryEncoder.transform([a])[0]]

# %%
data = map(process_line, make_data_loader(develeopment=True))
data = list(filter(lambda x: x, data))

# %%
from sklearn.model_selection import train_test_split
train_data, eval_data = train_test_split(data, test_size=0.1, random_state=1400, shuffle=False)

# %%
import numpy as np
num_labels = np.unique([i[1] for i in data]).__len__()

# %%
train_df = pd.DataFrame(train_data)
train_df.columns = ["text", "labels"]

# Preparing eval data
eval_df = pd.DataFrame(eval_data)
eval_df.columns = ["text", "labels"]

# Optional model configuration
model_args = ClassificationArgs(num_train_epochs=50, overwrite_output_dir=True)

# model_args["save_steps"] = -1
# model_args["save_model_every_epoch"] = False

# Create a ClassificationModel
model = ClassificationModel(
    'bert',
    # 'bert-base-cased',
    'outputs/checkpoint-3605-epoch-11',
    num_labels=num_labels,
    use_cuda=torch.cuda.is_available(),
    args=model_args
) 

# Train the model
model.train_model(train_df, acc=accuracy_score)

# Evaluate the model
result, model_outputs, wrong_predictions = model.eval_model(eval_df, acc=accuracy_score)
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/819 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_bert_128_31_2
# Epoch:   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:   Continuing training from checkpoint, will skip to saved global_step
# INFO:simpletransformers.classification.classification_model:   Continuing training from epoch 35
# INFO:simpletransformers.classification.classification_model:   Continuing training from global step 3605
# INFO:simpletransformers.classification.classification_model:   Will skip the first 0 steps in the current epoch
# Running Epoch 0 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 1 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 2 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 3 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 4 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 5 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 6 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 7 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 8 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 9 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 10 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 11 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 12 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 13 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# Running Epoch 14 of 50:   0%|          | 0/103 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model: Training of bert model complete. Saved to outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/91 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_bert_128_31_2
# Running Evaluation:   0%|          | 0/12 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.9768344846912344, 'acc': 0.978021978021978, 'eval_loss': 0.14093771328528723}

# %%
data_test = map(process_line, make_data_loader(develeopment=False))
data_test = filter(lambda x: x, data_test)
X_test, y_true = [], []
for x, y in data_test:
  X_test.append(x)
  y_true.append(y)

# %%
# # Make predictions with the model
predictions, raw_outputs = model.predict(X_test)
# Out:
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/387 [00:00<?, ?it/s]
#   0%|          | 0/49 [00:00<?, ?it/s]

# %%
print('accuracy >> ', accuracy_score(y_true, predictions))
# Out:
# accuracy >>  0.9095607235142119

# %%
rm -rf outputs/*

# %%
# !zip outputs/checkpoint-5150-epoch-15 model.zip
# Out:
# 	zip warning: name not matched: model.zip
#
# zip error: Nothing to do! (outputs/checkpoint-5150-epoch-15.zip)

# %%
# !mv data/checkpoint-5150-epoch-15 outputs

# %%
# !zip -r outputs.zip outputs/
# Out:
#   adding: outputs/ (stored 0%)
#   adding: outputs/checkpoint-5150-epoch-15/ (stored 0%)
#   adding: outputs/checkpoint-5150-epoch-15/scheduler.pt (deflated 49%)
#   adding: outputs/checkpoint-5150-epoch-15/pytorch_model.bin (deflated 7%)
#   adding: outputs/checkpoint-5150-epoch-15/training_args.bin (deflated 48%)
#   adding: outputs/checkpoint-5150-epoch-15/optimizer.pt (deflated 27%)
#   adding: outputs/checkpoint-5150-epoch-15/model_args.json (deflated 62%)
#   adding: outputs/checkpoint-5150-epoch-15/special_tokens_map.json (deflated 40%)
#   adding: outputs/checkpoint-5150-epoch-15/tokenizer.json (deflated 57%)
#   adding: outputs/checkpoint-5150-epoch-15/vocab.txt (deflated 49%)
#   adding: outputs/checkpoint-5150-epoch-15/config.json (deflated 65%)
#   adding: outputs/checkpoint-5150-epoch-15/tokenizer_config.json (deflated 38%)
#   adding: outputs/.ipynb_checkpoints/ (stored 0%)
